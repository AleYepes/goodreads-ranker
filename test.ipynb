# %%
import sqlite3

import pandas as pd

# Establish a connection to the SQLite database
conn = sqlite3.connect("data/goodreads.db")

# Load the books table into a DataFrame
df = pd.read_sql_query("SELECT * FROM books", conn)

# Close the connection
conn.close()

# Preview the data
df

# %%
df[df['similar_books'] == '']
